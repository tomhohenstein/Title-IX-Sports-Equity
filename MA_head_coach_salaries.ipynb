# %%
import pandas as pd
# http://pandas.pydata.org/

# %%
df = pd.read_excel("../Title-IX-Working-Folder/instLevel.xlsx", sheetname=0)
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html

# %%
df.head()
# Out:
#    unitid                     institution_name  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100706  University of Alabama in Huntsville
# 3  100724             Alabama State University
# 4  100751            The University of Alabama
#
#                         addr1_txt addr2_txt    city_txt state_cd   zip_text  \
# 0            4900 Meridian Street       NaN      Normal       AL      35762
# 1  Administration Bldg Suite 1070       NaN  Birmingham       AL  352940110
# 2                 301 Sparkman Dr       NaN  Huntsville       AL      35899
# 3            915 S Jackson Street       NaN  Montgomery       AL  361040271
# 4             739 University Blvd       NaN  Tuscaloosa       AL  354870166
#
#    ClassificationCode                  classification_name  \
# 0                   2                   NCAA Division I-AA
# 1                   1                    NCAA Division I-A
# ...

# %%
list(df.columns.values)
# Out:
# [u'unitid',
#  u'institution_name',
#  u'addr1_txt',
#  u'addr2_txt',
#  u'city_txt',
#  u'state_cd',
#  u'zip_text',
#  u'ClassificationCode',
#  u'classification_name',
#  u'ClassificationOther',
#  u'EFMaleCount',
#  u'EFFemaleCount',
#  u'EFTotalCount',
#  u'sector_cd',
#  u'sector_name',
#  u'STUDENTAID_MEN',
#  u'STUDENTAID_WOMEN',
#  u'STUDENTAID_COED',
#  u'STUDENTAID_TOTAL',
#  u'STUAID_MEN_RATIO',
#  u'STUAID_WOMEN_RATIO',
#  u'STUAID_COED_RATIO',
#  u'RECRUITEXP_MEN',
#  u'RECRUITEXP_WOMEN',
#  u'RECRUITEXP_COED',
#  u'RECRUITEXP_TOTAL',
#  u'HDCOACH_SALARY_MEN',
#  u'HDCOACH_SALARY_WOMEN',
#  u'HDCOACH_SALARY_COED',
#  u'NUM_HDCOACH_MEN',
#  u'NUM_HDCOACH_WOMEN',
#  u'NUM_HDCOACH_COED',
#  u'HDCOACH_SAL_FTE_MEN',
#  u'HDCOACH_SAL_FTE_WOMN',
#  u'HDCOACH_SAL_FTE_COED',
#  u'FTE_HDCOACH_MEN',
#  u'FTE_HDCOACH_WOMEN',
#  u'FTE_HDCOACH_COED',
#  u'ASCOACH_SALARY_MEN',
#  u'ASCOACH_SALARY_WOMEN',
#  u'ASCOACH_SALARY_COED',
#  u'NUM_ASCOACH_MEN',
#  u'NUM_ASCOACH_WOMEN',
# ...

# %%
# READ HERE!!!
#
#  sector names for both public and private 4 year colleges/universities.
# see https://docs.python.org/2/reference/expressions.html#operator-precedence
# 
# The operator you're looking for is | aka or 
#
# Try something like: new dataframe = df[ ( df["column header"] == "thing you want - Public, 4 year or aboive" ) | df["column header"] == "thing you want - Public, 4 year or aboive" )]
#

# %%
# READ HERE!!! 
#
# The other thing I want to do is to remove categories: #4,7,8,14,16-26,39 - onwards#
# http://stackoverflow.com/questions/14363640/python-pandas-deleting-multiple-series-from-a-data-frame-in-one-command
#
# try something like: new data frame= df.drop(['column header','column header 2'], axis=1)

# %%
df.drop(df.columns[38:], inplace=True, axis=1)
df.drop(df.columns[15:28], inplace=True, axis=1)
df.drop(df.columns[2:4], inplace=True, axis=1)

# %%
ma_df = df[(df["state_cd"] == "MA")]
print(ma_df.shape)
ma_df.head()
# Out:
# (64, 167)
#      unitid                institution_name          addr1_txt addr2_txt  \
# 768  164447  American International College  1000 State Street       NaN
# 769  164465                 Amherst College    Boltwood Avenue       NaN
# 770  164492              Anna Maria College     50 Sunset Lane       NaN
# 771  164562              Assumption College   500 Salisbury St       NaN
# 772  164580                  Babson College  231 Forest Street       NaN
#
#         city_txt state_cd  zip_text  ClassificationCode  \
# 768  Springfield       MA      1109                   4
# 769      Amherst       MA  10025000                   6
# 770       Paxton       MA  16121198                   6
# 771    Worcester       MA  16091296                   4
# 772    Wellesley       MA  24570310                   7
#
#                       classification_name ClassificationOther  \
# 768      NCAA Division II (with football)                 NaN
# ...

# %%
ma_df.to_csv("../Title-IX-Working-Folder/MA_head_coach_salaries.csv")
